# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %% [markdown]
# Medipipe Setup

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %% [markdown]
# Test Mediapipe

# %%
with mp_holistic.Holistic(min_detection_confidence=0.9, min_tracking_confidence=0.5) as holistic:
    # Read image using cv2
    img = cv2.imread('C:/Users/StrawHat/Pictures/images/WIN_20240221_16_53_01_Pro.jpg')
    
    # Check if the image is empty
    if img is not None:
        image, results = mediapipe_detection(img, holistic)
        print(results)
        draw_styled_landmarks(image, results)
        plt.figure(figsize=(18,18))
        plt.imshow(image)  # Convert image data to the correct data type
    else:
        print("Failed to read the image.")
# Out:
# Failed to read the image.

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.3, min_tracking_confidence=0.3) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)

        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
'''
draw_landmarks(frame, results)
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
'''
# Out:
# '\ndraw_landmarks(frame, results)\nplt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))\n'

# %%
'''len(results.left_hand_landmarks.landmark)'''
# Out:
# 'len(results.left_hand_landmarks.landmark)'

# %%
'''pose = []
for res in results.pose_landmarks.landmark:
    test = np.array([res.x, res.y, res.z, res.visibility])
    pose.append(test)'''
# Out:
# 'pose = []\nfor res in results.pose_landmarks.landmark:\n    test = np.array([res.x, res.y, res.z, res.visibility])\n    pose.append(test)'

# %%
'''pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
'''
# Out:
# 'pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)\nface = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)\nlh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)\nrh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)\n'

# %%
#for testing
'''face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
face'''
# Out:
# 'face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)\nface'

# %% [markdown]
# Data Extraction

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %%
#for testing
'''result_test = extract_keypoints(results)
result_test'''
# Out:
# 'result_test = extract_keypoints(results)\nresult_test'

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('MP_Data') 

# Actions that we try to detect
actions = np.array(['A', 'B', 'C', 'D', 'E', 'F', 'G'])

# Thirty videos worth of data
no_sequences = 40

# Videos are going to be 30 frames in length
sequence_length = 30

# Folder start
start_folder = 40

# %%
for action in actions:
    for sequence in range(no_sequences):
        try:
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:

    # NEW LOOP
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(no_sequences):
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, holistic)

                # Draw landmarks
                draw_styled_landmarks(image, results)

                # NEW Apply wait logic
                if frame_num == 0:
                    cv2.putText(image, 'STARTING COLLECTION', (120, 200),
                                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15, 12),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(1000)
                else:
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15, 12),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)

                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(
                    DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break

    cap.release()
    cv2.destroyAllWindows()

# %% [markdown]
# Model Building

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}
label_map
# Out:
# {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
print(np.array(sequences).shape)
print(np.array(labels).shape)
# Out:
# (280, 30, 1662)
# (280,)

# %%
X = np.array(sequences)
X.shape
# Out:
# (280, 30, 1662)

# %%
y = to_categorical(labels).astype(int)
y.shape
# Out:
# (280, 7)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
print(X_train.shape)
print(X_test.shape) 
print(y_train.shape)
print(y_test.shape)
# Out:
# (266, 30, 1662)
# (14, 30, 1662)
# (266, 7)
# (14, 7)

# %%
from tensorflow.keras.callbacks import TensorBoard

# Define TensorBoard callback
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Define EarlyStopping callback
early_stopping_callback = EarlyStopping(
    monitor='accuracy',        # Can be 'val_accuracy', 'accuracy', etc.
    patience=30,               # Number of epochs with no improvement after which training will be stopped
    restore_best_weights=True  # Whether to restore model weights from the epoch with the best value of the monitored quantity
)

# %% [markdown]
# LSTM and Dropout

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization

# Define the model
model = Sequential()

# First LSTM layer with dropout and batch normalization
model.add(LSTM(256, return_sequences=True, input_shape=(30, 1662)))
model.add(Dropout(0.4))  # Dropout for regularization
model.add(BatchNormalization())  # Batch normalization for stable learning

# Second LSTM layer with dropout and batch normalization
model.add(LSTM(128, return_sequences=True))
model.add(Dropout(0.4))
model.add(BatchNormalization())

# Third LSTM layer with dropout and batch normalization
model.add(LSTM(64, return_sequences=True))
model.add(Dropout(0.4))
model.add(BatchNormalization())

# Fourth LSTM layer with dropout and batch normalization
model.add(LSTM(32))
model.add(Dropout(0.4))
model.add(BatchNormalization())

# Fully connected dense layers
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.4))  # Dropout for regularization

model.add(Dense(32, activation='relu'))
model.add(Dropout(0.3))  # Dropout for regularization

# Output layer for multi-class classification (7 classes)
model.add(Dense(7, activation='softmax'))

# Compile the model with sparse_categorical_crossentropy
model.compile(optimizer='adam', 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

# Print model summary
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_38 (LSTM)              (None, 30, 256)           1965056
#
#  dropout_59 (Dropout)        (None, 30, 256)           0
#
#  batch_normalization_37 (Bat  (None, 30, 256)          1024
#  chNormalization)
#
#  lstm_39 (LSTM)              (None, 30, 128)           197120
#
#  dropout_60 (Dropout)        (None, 30, 128)           0
#
#  batch_normalization_38 (Bat  (None, 30, 128)          512
#  chNormalization)
#
#  lstm_40 (LSTM)              (None, 30, 64)            49408
#
#  dropout_61 (Dropout)        (None, 30, 64)            0
#
#  batch_normalization_39 (Bat  (None, 30, 64)           256
#  chNormalization)
#
#  lstm_41 (LSTM)              (None, 32)                12416
#
#  dropout_62 (Dropout)        (None, 32)                0
#
#  batch_normalization_40 (Bat  (None, 32)               128
#  chNormalization)
#
#  dense_33 (Dense)            (None, 64)                2112
#
#  dropout_63 (Dropout)        (None, 64)                0
#
#  dense_34 (Dense)            (None, 32)                2080
#
#  dropout_64 (Dropout)        (None, 32)                0
#
#  dense_35 (Dense)            (None, 7)                 231
#
# =================================================================
# Total params: 2,230,343
# Trainable params: 2,229,383
# Non-trainable params: 960
# _________________________________________________________________

# %% [markdown]
# Model Training

# %%
# Fit the model with both TensorBoard and EarlyStopping callbacks
history = model.fit(
    X_train, y_train,
    epochs=2000,
    validation_data=(X_test, y_test),
    callbacks=[tb_callback]
)
# Out:
# Epoch 1/2000
# 9/9 [==============================] - 9s 271ms/step - loss: 2.1751 - accuracy: 0.1429 - val_loss: 1.9561 - val_accuracy: 0.2143
# Epoch 2/2000
# 9/9 [==============================] - 1s 108ms/step - loss: 2.0142 - accuracy: 0.1805 - val_loss: 1.9877 - val_accuracy: 0.0000e+00
# Epoch 3/2000
# 9/9 [==============================] - 1s 94ms/step - loss: 1.9131 - accuracy: 0.2331 - val_loss: 2.0166 - val_accuracy: 0.0000e+00
# Epoch 4/2000
# 9/9 [==============================] - 1s 89ms/step - loss: 1.8251 - accuracy: 0.2932 - val_loss: 2.0626 - val_accuracy: 0.0000e+00
# Epoch 5/2000
# 9/9 [==============================] - 1s 96ms/step - loss: 1.7533 - accuracy: 0.2857 - val_loss: 2.0871 - val_accuracy: 0.0714
# Epoch 6/2000
# 9/9 [==============================] - 1s 87ms/step - loss: 1.7063 - accuracy: 0.2782 - val_loss: 2.0970 - val_accuracy: 0.0714
# Epoch 7/2000
# 9/9 [==============================] - 1s 83ms/step - loss: 1.5492 - accuracy: 0.3985 - val_loss: 2.1798 - val_accuracy: 0.0714
# Epoch 8/2000
# 9/9 [==============================] - 1s 93ms/step - loss: 1.4906 - accuracy: 0.4173 - val_loss: 2.3455 - val_accuracy: 0.0714
# Epoch 9/2000
# 9/9 [==============================] - 1s 87ms/step - loss: 1.4657 - accuracy: 0.4098 - val_loss: 2.4313 - val_accuracy: 0.1429
# Epoch 10/2000
# 9/9 [==============================] - 1s 112ms/step - loss: 1.4902 - accuracy: 0.3985 - val_loss: 2.4560 - val_accuracy: 0.1429
# Epoch 11/2000
# 9/9 [==============================] - 1s 120ms/step - loss: 1.4004 - accuracy: 0.4286 - val_loss: 1.7466 - val_accuracy: 0.3571
# Epoch 12/2000
# 9/9 [==============================] - 1s 118ms/step - loss: 1.3755 - accuracy: 0.4586 - val_loss: 1.6236 - val_accuracy: 0.5714
# Epoch 13/2000
# 9/9 [==============================] - 1s 117ms/step - loss: 1.3289 - accuracy: 0.5000 - val_loss: 1.7727 - val_accuracy: 0.2857
# Epoch 14/2000
# 9/9 [==============================] - 1s 127ms/step - loss: 1.2678 - accuracy: 0.4737 - val_loss: 1.3718 - val_accuracy: 0.4286
# Epoch 15/2000
# 9/9 [==============================] - 1s 120ms/step - loss: 1.2380 - accuracy: 0.4925 - val_loss: 1.1231 - val_accuracy: 0.5000
# Epoch 16/2000
# 9/9 [==============================] - 1s 121ms/step - loss: 1.2031 - accuracy: 0.4887 - val_loss: 0.9832 - val_accuracy: 0.7857
# Epoch 17/2000
# 9/9 [==============================] - 1s 131ms/step - loss: 1.1389 - accuracy: 0.5000 - val_loss: 0.9072 - val_accuracy: 0.7857
# Epoch 18/2000
# 9/9 [==============================] - 1s 121ms/step - loss: 1.1022 - accuracy: 0.5376 - val_loss: 0.8020 - val_accuracy: 0.7143
# Epoch 19/2000
# 9/9 [==============================] - 1s 122ms/step - loss: 1.1384 - accuracy: 0.5602 - val_loss: 1.4848 - val_accuracy: 0.5000
# Epoch 20/2000
# 9/9 [==============================] - 1s 112ms/step - loss: 1.0139 - accuracy: 0.5865 - val_loss: 2.2248 - val_accuracy: 0.3571
# Epoch 21/2000
# 9/9 [==============================] - 1s 120ms/step - loss: 0.9637 - accuracy: 0.6053 - val_loss: 2.2637 - val_accuracy: 0.3571
# Epoch 22/2000
# 9/9 [==============================] - 1s 116ms/step - loss: 1.0357 - accuracy: 0.5150 - val_loss: 1.6045 - val_accuracy: 0.5000
# Epoch 23/2000
# 9/9 [==============================] - 1s 116ms/step - loss: 0.8857 - accuracy: 0.6541 - val_loss: 6.1663 - val_accuracy: 0.1429
# Epoch 24/2000
# 9/9 [==============================] - 1s 119ms/step - loss: 0.9046 - accuracy: 0.5865 - val_loss: 5.2427 - val_accuracy: 0.1429
# Epoch 25/2000
# 9/9 [==============================] - 1s 123ms/step - loss: 0.8264 - accuracy: 0.6015 - val_loss: 5.0940 - val_accuracy: 0.1429
# Epoch 26/2000
# 9/9 [==============================] - 1s 120ms/step - loss: 0.8469 - accuracy: 0.5977 - val_loss: 4.4481 - val_accuracy: 0.2857
# Epoch 27/2000
# 9/9 [==============================] - 1s 120ms/step - loss: 0.8005 - accuracy: 0.6654 - val_loss: 4.2893 - val_accuracy: 0.2857
# Epoch 28/2000
# 9/9 [==============================] - 1s 120ms/step - loss: 0.7684 - accuracy: 0.6992 - val_loss: 1.8509 - val_accuracy: 0.4286
# Epoch 29/2000
# 9/9 [==============================] - 1s 118ms/step - loss: 0.7274 - accuracy: 0.6729 - val_loss: 3.2869 - val_accuracy: 0.2857
# Epoch 30/2000
# 9/9 [==============================] - 1s 126ms/step - loss: 0.7665 - accuracy: 0.6391 - val_loss: 1.0926 - val_accuracy: 0.6429
# Epoch 31/2000
# 9/9 [==============================] - 1s 116ms/step - loss: 0.8052 - accuracy: 0.6391 - val_loss: 1.3017 - val_accuracy: 0.6429
# Epoch 32/2000
# 9/9 [==============================] - 1s 120ms/step - loss: 0.7437 - accuracy: 0.6391 - val_loss: 1.2363 - val_accuracy: 0.6429
# Epoch 33/2000
# 9/9 [==============================] - 1s 125ms/step - loss: 0.7784 - accuracy: 0.6541 - val_loss: 1.7800 - val_accuracy: 0.5000
# Epoch 34/2000
# 9/9 [==============================] - 1s 123ms/step - loss: 0.6703 - accuracy: 0.7105 - val_loss: 1.1828 - val_accuracy: 0.6429
# Epoch 35/2000
# 9/9 [==============================] - 1s 119ms/step - loss: 0.7825 - accuracy: 0.6504 - val_loss: 1.2170 - val_accuracy: 0.6429
# Epoch 36/2000
# 9/9 [==============================] - 1s 117ms/step - loss: 0.5633 - accuracy: 0.7481 - val_loss: 2.0495 - val_accuracy: 0.3571
# Epoch 37/2000
# 9/9 [==============================] - 1s 114ms/step - loss: 0.7416 - accuracy: 0.6955 - val_loss: 1.7507 - val_accuracy: 0.3571
# Epoch 38/2000
# 9/9 [==============================] - 1s 127ms/step - loss: 0.6932 - accuracy: 0.6917 - val_loss: 3.6959 - val_accuracy: 0.2143
# Epoch 39/2000
# 9/9 [==============================] - 1s 118ms/step - loss: 0.6824 - accuracy: 0.6880 - val_loss: 2.0825 - val_accuracy: 0.5000
# Epoch 40/2000
# 9/9 [==============================] - 1s 119ms/step - loss: 0.6891 - accuracy: 0.7143 - val_loss: 0.9655 - val_accuracy: 0.6429
# Epoch 41/2000
# 9/9 [==============================] - 1s 122ms/step - loss: 0.6705 - accuracy: 0.6880 - val_loss: 2.8883 - val_accuracy: 0.2857
# Epoch 42/2000
# 9/9 [==============================] - 1s 119ms/step - loss: 0.5935 - accuracy: 0.6767 - val_loss: 1.4285 - val_accuracy: 0.5714
# Epoch 43/2000
# 9/9 [==============================] - 1s 121ms/step - loss: 0.7224 - accuracy: 0.6429 - val_loss: 1.1766 - val_accuracy: 0.6429
# Epoch 44/2000
# 9/9 [==============================] - 1s 117ms/step - loss: 0.6797 - accuracy: 0.6992 - val_loss: 2.2852 - val_accuracy: 0.5000
# Epoch 45/2000
# 9/9 [==============================] - 1s 116ms/step - loss: 0.9422 - accuracy: 0.6391 - val_loss: 3.3036 - val_accuracy: 0.1429
# Epoch 46/2000
# 9/9 [==============================] - 1s 124ms/step - loss: 0.6725 - accuracy: 0.7143 - val_loss: 2.5758 - val_accuracy: 0.1429
# Epoch 47/2000
# 9/9 [==============================] - 1s 122ms/step - loss: 0.6483 - accuracy: 0.7368 - val_loss: 2.0636 - val_accuracy: 0.2857
# Epoch 48/2000
# 9/9 [==============================] - 1s 119ms/step - loss: 0.7548 - accuracy: 0.7143 - val_loss: 1.8280 - val_accuracy: 0.4286
# Epoch 49/2000
# 9/9 [==============================] - 1s 121ms/step - loss: 0.6714 - accuracy: 0.6880 - val_loss: 1.9882 - val_accuracy: 0.3571
# Epoch 50/2000
# 9/9 [==============================] - 1s 119ms/step - loss: 0.5518 - accuracy: 0.6992 - val_loss: 2.1281 - val_accuracy: 0.2143
# Epoch 51/2000
# 9/9 [==============================] - 1s 120ms/step - loss: 0.5047 - accuracy: 0.7218 - val_loss: 1.0708 - val_accuracy: 0.4286
# Epoch 52/2000
# 9/9 [==============================] - 1s 118ms/step - loss: 0.5292 - accuracy: 0.7970 - val_loss: 0.7942 - val_accuracy: 0.5714
# Epoch 53/2000
# 9/9 [==============================] - 1s 115ms/step - loss: 0.6026 - accuracy: 0.7331 - val_loss: 1.8300 - val_accuracy: 0.5714
# Epoch 54/2000
# 9/9 [==============================] - 1s 115ms/step - loss: 0.6228 - accuracy: 0.6955 - val_loss: 3.7861 - val_accuracy: 0.3571
# Epoch 55/2000
# 9/9 [==============================] - 1s 126ms/step - loss: 0.8795 - accuracy: 0.6579 - val_loss: 1.0630 - val_accuracy: 0.5714
# Epoch 56/2000
# 9/9 [==============================] - 1s 116ms/step - loss: 0.6530 - accuracy: 0.7406 - val_loss: 1.9512 - val_accuracy: 0.5714
# Epoch 57/2000
# 9/9 [==============================] - 1s 119ms/step - loss: 0.6983 - accuracy: 0.7180 - val_loss: 3.0242 - val_accuracy: 0.0714
# Epoch 58/2000
# 9/9 [==============================] - 1s 114ms/step - loss: 0.6066 - accuracy: 0.7293 - val_loss: 6.7692 - val_accuracy: 0.0714
# Epoch 59/2000
# 9/9 [==============================] - 1s 115ms/step - loss: 0.5669 - accuracy: 0.7632 - val_loss: 3.2462 - val_accuracy: 0.2143
# Epoch 60/2000
# 9/9 [==============================] - 1s 130ms/step - loss: 0.6959 - accuracy: 0.7293 - val_loss: 1.0956 - val_accuracy: 0.3571
# Epoch 61/2000
# 9/9 [==============================] - 1s 124ms/step - loss: 0.6962 - accuracy: 0.7068 - val_loss: 1.8995 - val_accuracy: 0.4286
# Epoch 62/2000
# 9/9 [==============================] - 1s 120ms/step - loss: 0.6809 - accuracy: 0.6880 - val_loss: 5.1165 - val_accuracy: 0.0714
# Epoch 63/2000
# 9/9 [==============================] - 1s 122ms/step - loss: 0.7942 - accuracy: 0.7143 - val_loss: 2.1771 - val_accuracy: 0.5000
# Epoch 64/2000
# 9/9 [==============================] - 1s 126ms/step - loss: 0.6815 - accuracy: 0.7331 - val_loss: 2.3949 - val_accuracy: 0.3571
# Epoch 65/2000
# 9/9 [==============================] - 1s 122ms/step - loss: 0.6219 - accuracy: 0.7444 - val_loss: 2.6742 - val_accuracy: 0.2857
# Epoch 66/2000
# 9/9 [==============================] - 1s 115ms/step - loss: 0.6046 - accuracy: 0.7331 - val_loss: 2.5112 - val_accuracy: 0.6429
# Epoch 67/2000
# 9/9 [==============================] - 1s 126ms/step - loss: 0.5672 - accuracy: 0.7293 - val_loss: 1.8308 - val_accuracy: 0.5000
# Epoch 68/2000
# 9/9 [==============================] - 1s 122ms/step - loss: 0.6323 - accuracy: 0.7519 - val_loss: 1.1750 - val_accuracy: 0.6429
# Epoch 69/2000
# 9/9 [==============================] - 1s 114ms/step - loss: 0.6003 - accuracy: 0.7293 - val_loss: 2.3770 - val_accuracy: 0.4286
# Epoch 70/2000
# 9/9 [==============================] - 1s 116ms/step - loss: 0.5058 - accuracy: 0.7857 - val_loss: 4.8893 - val_accuracy: 0.2857
# Epoch 71/2000
# 9/9 [==============================] - 1s 122ms/step - loss: 0.6765 - accuracy: 0.7519 - val_loss: 1.5077 - val_accuracy: 0.6429
# Epoch 72/2000
# 9/9 [==============================] - 1s 116ms/step - loss: 0.4915 - accuracy: 0.7782 - val_loss: 2.1449 - val_accuracy: 0.5714
# Epoch 73/2000
# 9/9 [==============================] - 1s 114ms/step - loss: 0.5167 - accuracy: 0.7895 - val_loss: 1.6865 - val_accuracy: 0.6429
# Epoch 74/2000
# 9/9 [==============================] - 1s 119ms/step - loss: 0.5823 - accuracy: 0.7556 - val_loss: 2.2522 - val_accuracy: 0.3571
# Epoch 75/2000
# 9/9 [==============================] - 1s 120ms/step - loss: 0.5696 - accuracy: 0.7820 - val_loss: 2.2493 - val_accuracy: 0.5000
# Epoch 76/2000
# 9/9 [==============================] - 1s 121ms/step - loss: 0.4691 - accuracy: 0.8195 - val_loss: 2.7145 - val_accuracy: 0.2857
# Epoch 77/2000
# 9/9 [==============================] - 1s 120ms/step - loss: 0.5235 - accuracy: 0.8158 - val_loss: 4.1957 - val_accuracy: 0.2143
# Epoch 78/2000
# 9/9 [==============================] - 1s 123ms/step - loss: 0.5028 - accuracy: 0.7669 - val_loss: 5.0433 - val_accuracy: 0.2857
# Epoch 79/2000
# 9/9 [==============================] - 1s 119ms/step - loss: 0.4274 - accuracy: 0.8008 - val_loss: 5.0977 - val_accuracy: 0.2857
# Epoch 80/2000
# 9/9 [==============================] - 1s 116ms/step - loss: 0.4813 - accuracy: 0.7857 - val_loss: 5.4906 - val_accuracy: 0.2857
# Epoch 81/2000
# 9/9 [==============================] - 1s 127ms/step - loss: 0.5553 - accuracy: 0.8271 - val_loss: 5.4178 - val_accuracy: 0.2857
# Epoch 82/2000
# 9/9 [==============================] - 1s 119ms/step - loss: 0.4770 - accuracy: 0.8083 - val_loss: 1.4033 - val_accuracy: 0.7143
# Epoch 83/2000
# 9/9 [==============================] - 1s 117ms/step - loss: 0.4933 - accuracy: 0.7857 - val_loss: 2.0822 - val_accuracy: 0.6429
# Epoch 84/2000
# 9/9 [==============================] - 1s 121ms/step - loss: 0.6013 - accuracy: 0.7406 - val_loss: 1.5536 - val_accuracy: 0.5714
# Epoch 85/2000
# 9/9 [==============================] - 1s 121ms/step - loss: 0.7057 - accuracy: 0.7180 - val_loss: 1.0293 - val_accuracy: 0.5714
# Epoch 86/2000
# 9/9 [==============================] - 1s 116ms/step - loss: 0.5256 - accuracy: 0.8083 - val_loss: 2.0387 - val_accuracy: 0.6429
# Epoch 87/2000
# 9/9 [==============================] - 1s 117ms/step - loss: 0.5948 - accuracy: 0.7481 - val_loss: 0.9187 - val_accuracy: 0.7143
# Epoch 88/2000
# 9/9 [==============================] - 1s 125ms/step - loss: 0.5528 - accuracy: 0.7744 - val_loss: 1.4074 - val_accuracy: 0.4286
# Epoch 89/2000
# 9/9 [==============================] - 1s 112ms/step - loss: 0.5804 - accuracy: 0.7406 - val_loss: 2.1788 - val_accuracy: 0.3571
# Epoch 90/2000
# 9/9 [==============================] - 1s 132ms/step - loss: 0.5046 - accuracy: 0.7331 - val_loss: 1.6139 - val_accuracy: 0.5000
# Epoch 91/2000
# 9/9 [==============================] - 1s 126ms/step - loss: 0.6095 - accuracy: 0.7556 - val_loss: 5.8731 - val_accuracy: 0.2143
# Epoch 92/2000
# 9/9 [==============================] - 1s 130ms/step - loss: 0.4361 - accuracy: 0.7932 - val_loss: 10.2596 - val_accuracy: 0.1429
# Epoch 93/2000
# 9/9 [==============================] - 1s 139ms/step - loss: 0.4499 - accuracy: 0.8045 - val_loss: 9.6571 - val_accuracy: 0.2143
# Epoch 94/2000
# 9/9 [==============================] - 1s 141ms/step - loss: 0.5050 - accuracy: 0.7782 - val_loss: 8.4561 - val_accuracy: 0.2857
# Epoch 95/2000
# 9/9 [==============================] - 1s 100ms/step - loss: 0.4160 - accuracy: 0.8271 - val_loss: 6.1082 - val_accuracy: 0.3571
# Epoch 96/2000
# 9/9 [==============================] - 1s 88ms/step - loss: 0.4857 - accuracy: 0.7970 - val_loss: 7.2181 - val_accuracy: 0.2143
# Epoch 97/2000
# 9/9 [==============================] - 1s 92ms/step - loss: 0.3972 - accuracy: 0.8083 - val_loss: 2.3685 - val_accuracy: 0.6429
# Epoch 98/2000
# 9/9 [==============================] - 1s 90ms/step - loss: 0.3948 - accuracy: 0.8383 - val_loss: 2.6667 - val_accuracy: 0.6429
# Epoch 99/2000
# 9/9 [==============================] - 1s 87ms/step - loss: 0.4922 - accuracy: 0.7970 - val_loss: 6.7379 - val_accuracy: 0.1429
# Epoch 100/2000
# 9/9 [==============================] - 1s 82ms/step - loss: 0.5442 - accuracy: 0.8083 - val_loss: 10.3928 - val_accuracy: 0.1429
# Epoch 101/2000
# 9/9 [==============================] - 1s 82ms/step - loss: 0.4703 - accuracy: 0.7857 - val_loss: 3.4588 - val_accuracy: 0.2143
# Epoch 102/2000
# 9/9 [==============================] - 1s 83ms/step - loss: 0.4286 - accuracy: 0.7669 - val_loss: 5.2688 - val_accuracy: 0.2143
# Epoch 103/2000
# 9/9 [==============================] - 1s 80ms/step - loss: 0.5467 - accuracy: 0.8008 - val_loss: 4.8875 - val_accuracy: 0.1429
# Epoch 104/2000
# 9/9 [==============================] - 1s 81ms/step - loss: 0.5858 - accuracy: 0.7594 - val_loss: 8.2257 - val_accuracy: 0.2143
# Epoch 105/2000
# 9/9 [==============================] - 1s 84ms/step - loss: 0.5290 - accuracy: 0.8158 - val_loss: 1.7606 - val_accuracy: 0.7143
# Epoch 106/2000
# 9/9 [==============================] - 1s 80ms/step - loss: 0.5490 - accuracy: 0.7932 - val_loss: 0.6885 - val_accuracy: 0.7143
# Epoch 107/2000
# 9/9 [==============================] - 1s 84ms/step - loss: 0.3900 - accuracy: 0.8158 - val_loss: 4.4779 - val_accuracy: 0.2857
# Epoch 108/2000
# 9/9 [==============================] - 1s 84ms/step - loss: 0.5146 - accuracy: 0.8083 - val_loss: 2.2158 - val_accuracy: 0.5714
# Epoch 109/2000
# 9/9 [==============================] - 1s 81ms/step - loss: 0.3678 - accuracy: 0.8346 - val_loss: 1.7096 - val_accuracy: 0.6429
# Epoch 110/2000
# 9/9 [==============================] - 1s 87ms/step - loss: 0.5055 - accuracy: 0.7970 - val_loss: 0.9294 - val_accuracy: 0.7857
# Epoch 111/2000
# 9/9 [==============================] - 1s 84ms/step - loss: 0.3723 - accuracy: 0.8271 - val_loss: 2.0919 - val_accuracy: 0.4286
# Epoch 112/2000
# 9/9 [==============================] - 1s 87ms/step - loss: 0.4050 - accuracy: 0.7857 - val_loss: 3.8435 - val_accuracy: 0.2857
# Epoch 113/2000
# 9/9 [==============================] - 1s 89ms/step - loss: 0.4200 - accuracy: 0.8308 - val_loss: 1.5204 - val_accuracy: 0.7143
# Epoch 114/2000
# 9/9 [==============================] - 1s 87ms/step - loss: 0.4733 - accuracy: 0.8083 - val_loss: 5.3778 - val_accuracy: 0.2857
# Epoch 115/2000
# 9/9 [==============================] - 1s 83ms/step - loss: 0.3421 - accuracy: 0.8346 - val_loss: 2.0804 - val_accuracy: 0.5714
# Epoch 116/2000
# 9/9 [==============================] - 1s 85ms/step - loss: 0.3424 - accuracy: 0.8233 - val_loss: 4.4693 - val_accuracy: 0.3571
# Epoch 117/2000
# 9/9 [==============================] - 1s 86ms/step - loss: 0.3815 - accuracy: 0.8233 - val_loss: 9.3124 - val_accuracy: 0.2857
# Epoch 118/2000
# 9/9 [==============================] - 1s 85ms/step - loss: 0.3668 - accuracy: 0.8571 - val_loss: 6.9840 - val_accuracy: 0.4286
# Epoch 119/2000
# 9/9 [==============================] - 1s 83ms/step - loss: 0.3810 - accuracy: 0.8195 - val_loss: 3.8294 - val_accuracy: 0.6429
# Epoch 120/2000
# 9/9 [==============================] - 1s 82ms/step - loss: 0.4695 - accuracy: 0.7744 - val_loss: 3.0207 - val_accuracy: 0.5000
# Epoch 121/2000
# 9/9 [==============================] - 1s 83ms/step - loss: 0.5179 - accuracy: 0.7932 - val_loss: 3.7593 - val_accuracy: 0.3571
# Epoch 122/2000
# 9/9 [==============================] - 1s 83ms/step - loss: 0.6247 - accuracy: 0.7932 - val_loss: 7.6577 - val_accuracy: 0.2857
# Epoch 123/2000
# 9/9 [==============================] - 1s 82ms/step - loss: 0.5253 - accuracy: 0.8195 - val_loss: 8.9433 - val_accuracy: 0.1429
# Epoch 124/2000
# 9/9 [==============================] - 1s 82ms/step - loss: 0.5092 - accuracy: 0.7970 - val_loss: 1.5630 - val_accuracy: 0.6429
# Epoch 125/2000
# 9/9 [==============================] - 1s 85ms/step - loss: 0.5650 - accuracy: 0.8045 - val_loss: 4.4198 - val_accuracy: 0.3571
# Epoch 126/2000
# 9/9 [==============================] - 1s 82ms/step - loss: 0.4652 - accuracy: 0.8233 - val_loss: 0.5013 - val_accuracy: 0.7143
# Epoch 127/2000
# 9/9 [==============================] - 1s 88ms/step - loss: 0.4676 - accuracy: 0.7820 - val_loss: 3.9155 - val_accuracy: 0.4286
# Epoch 128/2000
# 9/9 [==============================] - 1s 82ms/step - loss: 0.5210 - accuracy: 0.8083 - val_loss: 0.6605 - val_accuracy: 0.8571
# Epoch 129/2000
# 9/9 [==============================] - 1s 85ms/step - loss: 0.5266 - accuracy: 0.7632 - val_loss: 2.8593 - val_accuracy: 0.2857
# Epoch 130/2000
# 9/9 [==============================] - 1s 81ms/step - loss: 0.4845 - accuracy: 0.7744 - val_loss: 0.9457 - val_accuracy: 0.7857
# Epoch 131/2000
# 9/9 [==============================] - 1s 83ms/step - loss: 0.3746 - accuracy: 0.7932 - val_loss: 1.3364 - val_accuracy: 0.7143
# Epoch 132/2000
# 9/9 [==============================] - 1s 86ms/step - loss: 0.4646 - accuracy: 0.7932 - val_loss: 3.0169 - val_accuracy: 0.3571
# Epoch 133/2000
# 9/9 [==============================] - 1s 83ms/step - loss: 0.3800 - accuracy: 0.8120 - val_loss: 0.3909 - val_accuracy: 0.8571
# Epoch 134/2000
# 9/9 [==============================] - 1s 82ms/step - loss: 0.3534 - accuracy: 0.8120 - val_loss: 1.9317 - val_accuracy: 0.6429
# Epoch 135/2000
# 9/9 [==============================] - 1s 81ms/step - loss: 0.3384 - accuracy: 0.8083 - val_loss: 4.2215 - val_accuracy: 0.2857
# Epoch 136/2000
# 9/9 [==============================] - 1s 83ms/step - loss: 0.3464 - accuracy: 0.8271 - val_loss: 6.8921 - val_accuracy: 0.0714
# Epoch 137/2000
# 9/9 [==============================] - 1s 84ms/step - loss: 0.3213 - accuracy: 0.8421 - val_loss: 2.4610 - val_accuracy: 0.3571
# Epoch 138/2000
# 9/9 [==============================] - 1s 81ms/step - loss: 0.3192 - accuracy: 0.8120 - val_loss: 1.8189 - val_accuracy: 0.6429
# Epoch 139/2000
# 9/9 [==============================] - 1s 83ms/step - loss: 0.3321 - accuracy: 0.8308 - val_loss: 1.7567 - val_accuracy: 0.7143
# Epoch 140/2000
# 9/9 [==============================] - 1s 81ms/step - loss: 0.3158 - accuracy: 0.8534 - val_loss: 1.4112 - val_accuracy: 0.6429
# Epoch 141/2000
# 9/9 [==============================] - 1s 89ms/step - loss: 0.3115 - accuracy: 0.8233 - val_loss: 3.9221 - val_accuracy: 0.5000
# Epoch 142/2000
# 9/9 [==============================] - 1s 83ms/step - loss: 0.3242 - accuracy: 0.8383 - val_loss: 2.0317 - val_accuracy: 0.7143
# Epoch 143/2000
# 9/9 [==============================] - 1s 83ms/step - loss: 0.3833 - accuracy: 0.8158 - val_loss: 1.3025 - val_accuracy: 0.7857
# Epoch 144/2000
# 9/9 [==============================] - 1s 82ms/step - loss: 0.4478 - accuracy: 0.8233 - val_loss: 9.7967 - val_accuracy: 0.1429
# Epoch 145/2000
# 9/9 [==============================] - 1s 85ms/step - loss: 0.3313 - accuracy: 0.8459 - val_loss: 5.3876 - val_accuracy: 0.5000
# Epoch 146/2000
# 9/9 [==============================] - 1s 88ms/step - loss: 0.4369 - accuracy: 0.8383 - val_loss: 5.9970 - val_accuracy: 0.2857
# Epoch 147/2000
# 9/9 [==============================] - 1s 82ms/step - loss: 0.3662 - accuracy: 0.8120 - val_loss: 8.3412 - val_accuracy: 0.2143
# Epoch 148/2000
# 9/9 [==============================] - 1s 85ms/step - loss: 0.4469 - accuracy: 0.7895 - val_loss: 4.1845 - val_accuracy: 0.3571
# Epoch 149/2000
# 9/9 [==============================] - 1s 82ms/step - loss: 0.3653 - accuracy: 0.8496 - val_loss: 6.9645 - val_accuracy: 0.2143
# Epoch 150/2000
# 9/9 [==============================] - 1s 83ms/step - loss: 0.4340 - accuracy: 0.7970 - val_loss: 3.7918 - val_accuracy: 0.4286
# Epoch 151/2000
# 9/9 [==============================] - 1s 83ms/step - loss: 0.3625 - accuracy: 0.8008 - val_loss: 0.0885 - val_accuracy: 0.9286
# Epoch 152/2000
# 9/9 [==============================] - 1s 82ms/step - loss: 0.3470 - accuracy: 0.8308 - val_loss: 1.4849 - val_accuracy: 0.7143
# Epoch 153/2000
# 9/9 [==============================] - 1s 85ms/step - loss: 0.3232 - accuracy: 0.8308 - val_loss: 0.3828 - val_accuracy: 0.9286
# Epoch 154/2000
# 9/9 [==============================] - 1s 86ms/step - loss: 0.4901 - accuracy: 0.8045 - val_loss: 5.5552 - val_accuracy: 0.2857
# Epoch 155/2000
# 9/9 [==============================] - 1s 81ms/step - loss: 0.4218 - accuracy: 0.8083 - val_loss: 1.8741 - val_accuracy: 0.4286
# Epoch 156/2000
# 9/9 [==============================] - 1s 82ms/step - loss: 0.3334 - accuracy: 0.8496 - val_loss: 7.3302 - val_accuracy: 0.2143
# Epoch 157/2000
# 9/9 [==============================] - 1s 84ms/step - loss: 0.3705 - accuracy: 0.8383 - val_loss: 7.3756 - val_accuracy: 0.2143
# Epoch 158/2000
# 9/9 [==============================] - 1s 83ms/step - loss: 0.2707 - accuracy: 0.8534 - val_loss: 5.6808 - val_accuracy: 0.2857
# Epoch 159/2000
# 9/9 [==============================] - 1s 82ms/step - loss: 0.3067 - accuracy: 0.8421 - val_loss: 5.6312 - val_accuracy: 0.2857
# Epoch 160/2000
# 9/9 [==============================] - 1s 90ms/step - loss: 0.3973 - accuracy: 0.8308 - val_loss: 4.2727 - val_accuracy: 0.4286
# Epoch 161/2000
# 9/9 [==============================] - 1s 84ms/step - loss: 0.3720 - accuracy: 0.8383 - val_loss: 0.4918 - val_accuracy: 0.9286
# Epoch 162/2000
# 9/9 [==============================] - 1s 90ms/step - loss: 0.2736 - accuracy: 0.8496 - val_loss: 4.5718 - val_accuracy: 0.4286
# Epoch 163/2000
# 9/9 [==============================] - 1s 99ms/step - loss: 0.3200 - accuracy: 0.8271 - val_loss: 4.3004 - val_accuracy: 0.4286
# Epoch 164/2000
# 9/9 [==============================] - 1s 86ms/step - loss: 0.2953 - accuracy: 0.8233 - val_loss: 0.2148 - val_accuracy: 0.9286
# Epoch 165/2000
# 9/9 [==============================] - 1s 85ms/step - loss: 0.2714 - accuracy: 0.8496 - val_loss: 0.0487 - val_accuracy: 1.0000
# Epoch 166/2000
# 9/9 [==============================] - 1s 84ms/step - loss: 0.2673 - accuracy: 0.8421 - val_loss: 1.7358 - val_accuracy: 0.7857
# Epoch 167/2000
# 9/9 [==============================] - 1s 84ms/step - loss: 0.2800 - accuracy: 0.8346 - val_loss: 1.7643 - val_accuracy: 0.7857
# Epoch 168/2000
# 9/9 [==============================] - 1s 86ms/step - loss: 0.3348 - accuracy: 0.8346 - val_loss: 0.4110 - val_accuracy: 0.9286
# Epoch 169/2000
# 9/9 [==============================] - 1s 84ms/step - loss: 0.2871 - accuracy: 0.8195 - val_loss: 4.0399 - val_accuracy: 0.5714
# Epoch 170/2000
# 9/9 [==============================] - 1s 81ms/step - loss: 0.3039 - accuracy: 0.8421 - val_loss: 3.2061 - val_accuracy: 0.6429
# Epoch 171/2000
# 9/9 [==============================] - 1s 84ms/step - loss: 0.7171 - accuracy: 0.8271 - val_loss: 6.2612 - val_accuracy: 0.2143
# Epoch 172/2000
# 9/9 [==============================] - 1s 85ms/step - loss: 0.9244 - accuracy: 0.6880 - val_loss: 4.1760 - val_accuracy: 0.2857
# Epoch 173/2000
# 9/9 [==============================] - 1s 83ms/step - loss: 0.8942 - accuracy: 0.6955 - val_loss: 2.9639 - val_accuracy: 0.2857
# Epoch 174/2000
# 9/9 [==============================] - 1s 84ms/step - loss: 0.5917 - accuracy: 0.7293 - val_loss: 1.5927 - val_accuracy: 0.6429
# Epoch 175/2000
# 9/9 [==============================] - 1s 83ms/step - loss: 0.5405 - accuracy: 0.7406 - val_loss: 1.6916 - val_accuracy: 0.5000
# Epoch 176/2000
# 9/9 [==============================] - 1s 81ms/step - loss: 0.5827 - accuracy: 0.7068 - val_loss: 2.6953 - val_accuracy: 0.2143
# Epoch 177/2000
# 9/9 [==============================] - 1s 82ms/step - loss: 0.8919 - accuracy: 0.7180 - val_loss: 3.1951 - val_accuracy: 0.2143
# Epoch 178/2000
# 9/9 [==============================] - 1s 83ms/step - loss: 1.8763 - accuracy: 0.5526 - val_loss: 3.5071 - val_accuracy: 0.4286
# Epoch 179/2000
# 9/9 [==============================] - 1s 82ms/step - loss: 1.2046 - accuracy: 0.6541 - val_loss: 2.1516 - val_accuracy: 0.4286
# Epoch 180/2000
# 9/9 [==============================] - 1s 83ms/step - loss: 0.9359 - accuracy: 0.6880 - val_loss: 2.2807 - val_accuracy: 0.3571
# Epoch 181/2000
# 9/9 [==============================] - 1s 92ms/step - loss: 0.7150 - accuracy: 0.7556 - val_loss: 2.4256 - val_accuracy: 0.5714
# Epoch 182/2000
# 9/9 [==============================] - 1s 105ms/step - loss: 0.5361 - accuracy: 0.7970 - val_loss: 3.2510 - val_accuracy: 0.3571
# Epoch 183/2000
# 9/9 [==============================] - 1s 85ms/step - loss: 0.5061 - accuracy: 0.8120 - val_loss: 3.9677 - val_accuracy: 0.4286
# Epoch 184/2000
# 9/9 [==============================] - 1s 91ms/step - loss: 0.4526 - accuracy: 0.8308 - val_loss: 1.6454 - val_accuracy: 0.5714
# Epoch 185/2000
# 9/9 [==============================] - 1s 91ms/step - loss: 0.4134 - accuracy: 0.8459 - val_loss: 2.8344 - val_accuracy: 0.5000
# Epoch 186/2000
# 9/9 [==============================] - 1s 85ms/step - loss: 0.3969 - accuracy: 0.8233 - val_loss: 4.2608 - val_accuracy: 0.5000
# Epoch 187/2000
# 9/9 [==============================] - 1s 83ms/step - loss: 0.3773 - accuracy: 0.8459 - val_loss: 1.4561 - val_accuracy: 0.6429
# Epoch 188/2000
# 9/9 [==============================] - 1s 83ms/step - loss: 0.3733 - accuracy: 0.8120 - val_loss: 3.2621 - val_accuracy: 0.4286
# Epoch 189/2000
# 9/9 [==============================] - 1s 122ms/step - loss: 0.4099 - accuracy: 0.8158 - val_loss: 2.4138 - val_accuracy: 0.5714
# Epoch 190/2000
# 9/9 [==============================] - 1s 120ms/step - loss: 0.3607 - accuracy: 0.8195 - val_loss: 1.2971 - val_accuracy: 0.7143
# Epoch 191/2000
# 9/9 [==============================] - 1s 127ms/step - loss: 0.5262 - accuracy: 0.8045 - val_loss: 2.6431 - val_accuracy: 0.5714
# Epoch 192/2000
# 9/9 [==============================] - 1s 120ms/step - loss: 0.5634 - accuracy: 0.7932 - val_loss: 4.6832 - val_accuracy: 0.2857
# Epoch 193/2000
# 9/9 [==============================] - 1s 125ms/step - loss: 0.4396 - accuracy: 0.8008 - val_loss: 4.2266 - val_accuracy: 0.2857
# Epoch 194/2000
# 9/9 [==============================] - 1s 127ms/step - loss: 0.7610 - accuracy: 0.7481 - val_loss: 9.4202 - val_accuracy: 0.0714
# Epoch 195/2000
# 9/9 [==============================] - 1s 120ms/step - loss: 0.7451 - accuracy: 0.7068 - val_loss: 8.6503 - val_accuracy: 0.0714
# Epoch 196/2000
# 9/9 [==============================] - 1s 123ms/step - loss: 0.5155 - accuracy: 0.7970 - val_loss: 7.2562 - val_accuracy: 0.0714
# Epoch 197/2000
# 9/9 [==============================] - 1s 124ms/step - loss: 0.5521 - accuracy: 0.7970 - val_loss: 6.5104 - val_accuracy: 0.2143
# Epoch 198/2000
# 9/9 [==============================] - 1s 129ms/step - loss: 0.4680 - accuracy: 0.7970 - val_loss: 4.3301 - val_accuracy: 0.4286
# Epoch 199/2000
# 9/9 [==============================] - 1s 122ms/step - loss: 0.5574 - accuracy: 0.8233 - val_loss: 1.7844 - val_accuracy: 0.5714
# Epoch 200/2000
# 9/9 [==============================] - 1s 122ms/step - loss: 0.4053 - accuracy: 0.8271 - val_loss: 1.1524 - val_accuracy: 0.7857
# Epoch 201/2000
# 9/9 [==============================] - 1s 123ms/step - loss: 0.4762 - accuracy: 0.8120 - val_loss: 3.0337 - val_accuracy: 0.2857
# Epoch 202/2000
# 9/9 [==============================] - 1s 120ms/step - loss: 0.4791 - accuracy: 0.8083 - val_loss: 1.1501 - val_accuracy: 0.7857
# Epoch 203/2000
# 9/9 [==============================] - 1s 122ms/step - loss: 0.4769 - accuracy: 0.7895 - val_loss: 2.5731 - val_accuracy: 0.5000
# Epoch 204/2000
# 9/9 [==============================] - 1s 121ms/step - loss: 0.4620 - accuracy: 0.8233 - val_loss: 6.5053 - val_accuracy: 0.2857
# Epoch 205/2000
# 9/9 [==============================] - 1s 127ms/step - loss: 0.4463 - accuracy: 0.8383 - val_loss: 4.4679 - val_accuracy: 0.4286
# Epoch 206/2000
# 9/9 [==============================] - 1s 124ms/step - loss: 0.4913 - accuracy: 0.7895 - val_loss: 5.6424 - val_accuracy: 0.3571
# Epoch 207/2000
# 9/9 [==============================] - 1s 126ms/step - loss: 0.3884 - accuracy: 0.7970 - val_loss: 2.4172 - val_accuracy: 0.5000
# Epoch 208/2000
# 9/9 [==============================] - 1s 127ms/step - loss: 0.3383 - accuracy: 0.8120 - val_loss: 0.3221 - val_accuracy: 0.8571
# Epoch 209/2000
# 9/9 [==============================] - 1s 120ms/step - loss: 0.3130 - accuracy: 0.8308 - val_loss: 1.1590 - val_accuracy: 0.7857
# Epoch 210/2000
# 9/9 [==============================] - 1s 125ms/step - loss: 0.3348 - accuracy: 0.8346 - val_loss: 2.0163 - val_accuracy: 0.5714
# Epoch 211/2000
# 9/9 [==============================] - 1s 122ms/step - loss: 0.3331 - accuracy: 0.8233 - val_loss: 0.9916 - val_accuracy: 0.7857
# Epoch 212/2000
# 9/9 [==============================] - 1s 128ms/step - loss: 0.3448 - accuracy: 0.8308 - val_loss: 5.9453 - val_accuracy: 0.3571
# Epoch 213/2000
# 9/9 [==============================] - 1s 126ms/step - loss: 0.3183 - accuracy: 0.8571 - val_loss: 4.4858 - val_accuracy: 0.3571
# Epoch 214/2000
# 9/9 [==============================] - 1s 121ms/step - loss: 0.3689 - accuracy: 0.8459 - val_loss: 5.0424 - val_accuracy: 0.3571
# Epoch 215/2000
# 9/9 [==============================] - 1s 119ms/step - loss: 0.2991 - accuracy: 0.8346 - val_loss: 3.1123 - val_accuracy: 0.5714
# Epoch 216/2000
# 9/9 [==============================] - 1s 128ms/step - loss: 0.2784 - accuracy: 0.8534 - val_loss: 0.0497 - val_accuracy: 1.0000
# Epoch 217/2000
# 9/9 [==============================] - 1s 124ms/step - loss: 0.3302 - accuracy: 0.8158 - val_loss: 0.1673 - val_accuracy: 0.9286
# Epoch 218/2000
# 9/9 [==============================] - 1s 121ms/step - loss: 0.3114 - accuracy: 0.8421 - val_loss: 0.2529 - val_accuracy: 0.9286
# Epoch 219/2000
# 9/9 [==============================] - 1s 125ms/step - loss: 0.2892 - accuracy: 0.8383 - val_loss: 1.5789 - val_accuracy: 0.7857
# Epoch 220/2000
# 9/9 [==============================] - 1s 129ms/step - loss: 0.2978 - accuracy: 0.8308 - val_loss: 2.4519 - val_accuracy: 0.7143
# Epoch 221/2000
# 9/9 [==============================] - 1s 118ms/step - loss: 0.2628 - accuracy: 0.8496 - val_loss: 0.7342 - val_accuracy: 0.9286
# Epoch 222/2000
# 9/9 [==============================] - 1s 123ms/step - loss: 0.2613 - accuracy: 0.8459 - val_loss: 2.5047 - val_accuracy: 0.6429
# Epoch 223/2000
# 9/9 [==============================] - 1s 119ms/step - loss: 0.3024 - accuracy: 0.8195 - val_loss: 2.5999 - val_accuracy: 0.7143
# Epoch 224/2000
# 9/9 [==============================] - 1s 122ms/step - loss: 0.3173 - accuracy: 0.8722 - val_loss: 0.0491 - val_accuracy: 1.0000
# Epoch 225/2000
# 9/9 [==============================] - 1s 128ms/step - loss: 0.2710 - accuracy: 0.8346 - val_loss: 0.6953 - val_accuracy: 0.7857
# Epoch 226/2000
# 9/9 [==============================] - 1s 123ms/step - loss: 0.2571 - accuracy: 0.8383 - val_loss: 2.0154 - val_accuracy: 0.7143
# Epoch 227/2000
# 9/9 [==============================] - 1s 122ms/step - loss: 0.2517 - accuracy: 0.8571 - val_loss: 4.2507 - val_accuracy: 0.3571
# Epoch 228/2000
# 9/9 [==============================] - 1s 121ms/step - loss: 0.2829 - accuracy: 0.8346 - val_loss: 1.2067 - val_accuracy: 0.7143
# Epoch 229/2000
# 9/9 [==============================] - 1s 126ms/step - loss: 0.3509 - accuracy: 0.8346 - val_loss: 0.3647 - val_accuracy: 0.8571
# Epoch 230/2000
# 9/9 [==============================] - 1s 126ms/step - loss: 0.3185 - accuracy: 0.8421 - val_loss: 1.6302 - val_accuracy: 0.7143
# Epoch 231/2000
# 9/9 [==============================] - 1s 120ms/step - loss: 0.3208 - accuracy: 0.8308 - val_loss: 2.3822 - val_accuracy: 0.6429
# Epoch 232/2000
# 9/9 [==============================] - 1s 126ms/step - loss: 0.3267 - accuracy: 0.8534 - val_loss: 2.0122 - val_accuracy: 0.7857
# Epoch 233/2000
# 9/9 [==============================] - 1s 121ms/step - loss: 0.3740 - accuracy: 0.8421 - val_loss: 3.8468 - val_accuracy: 0.5714
# Epoch 234/2000
# 9/9 [==============================] - 1s 125ms/step - loss: 0.3711 - accuracy: 0.8421 - val_loss: 0.5214 - val_accuracy: 0.9286
# Epoch 235/2000
# 9/9 [==============================] - 1s 126ms/step - loss: 0.2987 - accuracy: 0.8083 - val_loss: 0.0480 - val_accuracy: 1.0000
# Epoch 236/2000
# 9/9 [==============================] - 1s 122ms/step - loss: 0.3982 - accuracy: 0.8271 - val_loss: 0.0478 - val_accuracy: 1.0000
# Epoch 237/2000
# 9/9 [==============================] - 1s 121ms/step - loss: 0.3634 - accuracy: 0.8496 - val_loss: 0.0475 - val_accuracy: 1.0000
# Epoch 238/2000
# 9/9 [==============================] - 1s 128ms/step - loss: 0.3080 - accuracy: 0.8534 - val_loss: 0.1944 - val_accuracy: 0.9286
# Epoch 239/2000
# 9/9 [==============================] - 1s 128ms/step - loss: 0.2833 - accuracy: 0.8308 - val_loss: 0.2028 - val_accuracy: 0.9286
# Epoch 240/2000
# 9/9 [==============================] - 1s 126ms/step - loss: 0.2740 - accuracy: 0.8534 - val_loss: 2.2674 - val_accuracy: 0.5714
# Epoch 241/2000
# 9/9 [==============================] - 1s 124ms/step - loss: 0.2485 - accuracy: 0.8346 - val_loss: 1.8860 - val_accuracy: 0.7143
# Epoch 242/2000
# 9/9 [==============================] - 1s 120ms/step - loss: 0.2600 - accuracy: 0.8534 - val_loss: 1.3075 - val_accuracy: 0.7857
# Epoch 243/2000
# 9/9 [==============================] - 1s 125ms/step - loss: 0.2603 - accuracy: 0.8233 - val_loss: 0.0501 - val_accuracy: 0.9286
# Epoch 244/2000
# 9/9 [==============================] - 1s 124ms/step - loss: 0.2577 - accuracy: 0.8609 - val_loss: 0.0476 - val_accuracy: 1.0000
# Epoch 245/2000
# 9/9 [==============================] - 1s 122ms/step - loss: 0.2282 - accuracy: 0.8647 - val_loss: 0.0472 - val_accuracy: 1.0000
# Epoch 246/2000
# 9/9 [==============================] - 1s 122ms/step - loss: 0.2659 - accuracy: 0.8534 - val_loss: 0.4313 - val_accuracy: 0.9286
# Epoch 247/2000
# 9/9 [==============================] - 1s 129ms/step - loss: 0.3328 - accuracy: 0.8346 - val_loss: 0.1362 - val_accuracy: 0.8571
# Epoch 248/2000
# 9/9 [==============================] - 1s 121ms/step - loss: 0.3174 - accuracy: 0.8233 - val_loss: 1.7202 - val_accuracy: 0.8571
# Epoch 249/2000
# 9/9 [==============================] - 1s 122ms/step - loss: 0.2967 - accuracy: 0.8459 - val_loss: 2.4057 - val_accuracy: 0.7143
# Epoch 250/2000
# 9/9 [==============================] - 1s 117ms/step - loss: 0.3331 - accuracy: 0.8308 - val_loss: 0.7602 - val_accuracy: 0.9286
# Epoch 251/2000
# 9/9 [==============================] - 1s 132ms/step - loss: 0.3433 - accuracy: 0.8383 - val_loss: 3.0494 - val_accuracy: 0.5000
# Epoch 252/2000
# 9/9 [==============================] - 1s 124ms/step - loss: 0.2721 - accuracy: 0.8797 - val_loss: 4.5241 - val_accuracy: 0.4286
# Epoch 253/2000
# 9/9 [==============================] - 1s 124ms/step - loss: 0.2781 - accuracy: 0.8383 - val_loss: 6.6639 - val_accuracy: 0.3571
# Epoch 254/2000
# 9/9 [==============================] - 1s 129ms/step - loss: 0.2965 - accuracy: 0.8421 - val_loss: 4.9239 - val_accuracy: 0.5000
# Epoch 255/2000
# 9/9 [==============================] - 1s 122ms/step - loss: 0.3232 - accuracy: 0.8571 - val_loss: 3.3316 - val_accuracy: 0.6429
# Epoch 256/2000
# 9/9 [==============================] - 1s 123ms/step - loss: 0.2762 - accuracy: 0.9023 - val_loss: 2.8593 - val_accuracy: 0.7143
# Epoch 257/2000
# 9/9 [==============================] - 1s 125ms/step - loss: 0.3045 - accuracy: 0.8308 - val_loss: 1.7590 - val_accuracy: 0.7857
# Epoch 258/2000
# 9/9 [==============================] - 1s 134ms/step - loss: 0.2544 - accuracy: 0.8534 - val_loss: 0.6360 - val_accuracy: 0.9286
# Epoch 259/2000
# 9/9 [==============================] - 1s 130ms/step - loss: 0.2797 - accuracy: 0.8346 - val_loss: 0.0525 - val_accuracy: 0.9286
# Epoch 260/2000
# 9/9 [==============================] - 1s 122ms/step - loss: 0.2440 - accuracy: 0.8722 - val_loss: 0.8725 - val_accuracy: 0.8571
# Epoch 261/2000
# 9/9 [==============================] - 1s 129ms/step - loss: 0.2504 - accuracy: 0.8120 - val_loss: 0.8663 - val_accuracy: 0.8571
# Epoch 262/2000
# 9/9 [==============================] - 1s 122ms/step - loss: 0.2970 - accuracy: 0.8609 - val_loss: 0.0528 - val_accuracy: 0.9286
# Epoch 263/2000
# 9/9 [==============================] - 1s 132ms/step - loss: 0.3403 - accuracy: 0.8008 - val_loss: 9.1307 - val_accuracy: 0.0714
# Epoch 264/2000
# 9/9 [==============================] - 1s 127ms/step - loss: 0.4713 - accuracy: 0.8045 - val_loss: 2.3429 - val_accuracy: 0.7143
# Epoch 265/2000
# 9/9 [==============================] - 1s 120ms/step - loss: 0.2788 - accuracy: 0.8308 - val_loss: 0.0704 - val_accuracy: 1.0000
# Epoch 266/2000
# 9/9 [==============================] - 1s 129ms/step - loss: 0.2919 - accuracy: 0.8534 - val_loss: 4.3494 - val_accuracy: 0.5000
# Epoch 267/2000
# 9/9 [==============================] - 1s 124ms/step - loss: 0.3142 - accuracy: 0.8496 - val_loss: 2.7913 - val_accuracy: 0.6429
# Epoch 268/2000
# 9/9 [==============================] - 1s 124ms/step - loss: 0.3323 - accuracy: 0.8346 - val_loss: 1.4866 - val_accuracy: 0.7857
# Epoch 269/2000
# 9/9 [==============================] - 1s 121ms/step - loss: 0.2472 - accuracy: 0.8647 - val_loss: 1.0308 - val_accuracy: 0.8571
# Epoch 270/2000
# 9/9 [==============================] - 1s 133ms/step - loss: 0.2967 - accuracy: 0.8383 - val_loss: 1.3677 - val_accuracy: 0.8571
# Epoch 271/2000
# 9/9 [==============================] - 1s 124ms/step - loss: 0.2954 - accuracy: 0.8496 - val_loss: 5.4177 - val_accuracy: 0.5000
# Epoch 272/2000
# 9/9 [==============================] - 1s 119ms/step - loss: 0.2635 - accuracy: 0.8195 - val_loss: 6.5104 - val_accuracy: 0.2857
# Epoch 273/2000
# 9/9 [==============================] - 1s 119ms/step - loss: 0.2427 - accuracy: 0.8383 - val_loss: 6.2731 - val_accuracy: 0.5000
# Epoch 274/2000
# 9/9 [==============================] - 1s 122ms/step - loss: 0.2904 - accuracy: 0.8571 - val_loss: 4.7459 - val_accuracy: 0.5714
# Epoch 275/2000
# 9/9 [==============================] - 1s 121ms/step - loss: 0.2528 - accuracy: 0.8308 - val_loss: 1.8243 - val_accuracy: 0.8571
# Epoch 276/2000
# 9/9 [==============================] - 1s 125ms/step - loss: 0.2511 - accuracy: 0.8271 - val_loss: 1.2868 - val_accuracy: 0.8571
# Epoch 277/2000
# 9/9 [==============================] - 1s 121ms/step - loss: 0.2471 - accuracy: 0.8383 - val_loss: 1.9279 - val_accuracy: 0.7857
# Epoch 278/2000
# 9/9 [==============================] - 1s 121ms/step - loss: 0.2450 - accuracy: 0.8346 - val_loss: 0.8252 - val_accuracy: 0.8571
# Epoch 279/2000
# 9/9 [==============================] - 1s 126ms/step - loss: 0.2962 - accuracy: 0.8308 - val_loss: 0.7922 - val_accuracy: 0.8571
# Epoch 280/2000
# 9/9 [==============================] - 1s 121ms/step - loss: 0.2866 - accuracy: 0.8233 - val_loss: 2.4552 - val_accuracy: 0.7143
# Epoch 281/2000
# 9/9 [==============================] - 1s 126ms/step - loss: 0.2879 - accuracy: 0.8684 - val_loss: 1.3983 - val_accuracy: 0.9286
# Epoch 282/2000
# 9/9 [==============================] - 1s 128ms/step - loss: 0.3134 - accuracy: 0.8647 - val_loss: 4.5767 - val_accuracy: 0.5714
# Epoch 283/2000
# 9/9 [==============================] - 1s 122ms/step - loss: 0.3012 - accuracy: 0.8421 - val_loss: 2.2033 - val_accuracy: 0.7857
# Epoch 284/2000
# 9/9 [==============================] - 1s 128ms/step - loss: 0.5966 - accuracy: 0.7932 - val_loss: 6.1660 - val_accuracy: 0.3571
# Epoch 285/2000
# 9/9 [==============================] - 1s 128ms/step - loss: 0.6176 - accuracy: 0.8045 - val_loss: 6.0158 - val_accuracy: 0.1429
# Epoch 286/2000
# 9/9 [==============================] - 1s 129ms/step - loss: 0.4077 - accuracy: 0.8120 - val_loss: 7.3268 - val_accuracy: 0.0714
# Epoch 287/2000
# 9/9 [==============================] - 1s 128ms/step - loss: 0.3393 - accuracy: 0.8271 - val_loss: 6.3944 - val_accuracy: 0.1429
# Epoch 288/2000
# 9/9 [==============================] - 1s 124ms/step - loss: 0.3188 - accuracy: 0.8647 - val_loss: 4.1386 - val_accuracy: 0.5000
# Epoch 289/2000
# 9/9 [==============================] - 1s 111ms/step - loss: 0.3756 - accuracy: 0.8496 - val_loss: 2.4761 - val_accuracy: 0.6429
# Epoch 290/2000
# 9/9 [==============================] - 1s 87ms/step - loss: 0.6323 - accuracy: 0.7444 - val_loss: 2.9066 - val_accuracy: 0.6429
# Epoch 291/2000
# 9/9 [==============================] - 1s 83ms/step - loss: 0.5203 - accuracy: 0.7782 - val_loss: 5.9649 - val_accuracy: 0.2857
# Epoch 292/2000
# 9/9 [==============================] - 1s 87ms/step - loss: 0.5628 - accuracy: 0.8195 - val_loss: 0.9007 - val_accuracy: 0.9286
# Epoch 293/2000
# 9/9 [==============================] - 1s 89ms/step - loss: 0.4007 - accuracy: 0.8045 - val_loss: 1.0416 - val_accuracy: 0.8571
# Epoch 294/2000
# 9/9 [==============================] - 1s 87ms/step - loss: 0.4002 - accuracy: 0.8233 - val_loss: 7.6006 - val_accuracy: 0.1429
# Epoch 295/2000
# 9/9 [==============================] - 1s 88ms/step - loss: 0.3597 - accuracy: 0.8271 - val_loss: 7.2802 - val_accuracy: 0.2857
# Epoch 296/2000
# 9/9 [==============================] - 1s 84ms/step - loss: 0.4090 - accuracy: 0.8233 - val_loss: 5.9481 - val_accuracy: 0.2857
# Epoch 297/2000
# 9/9 [==============================] - 1s 86ms/step - loss: 0.3287 - accuracy: 0.8233 - val_loss: 5.4808 - val_accuracy: 0.3571
# Epoch 298/2000
# 9/9 [==============================] - 1s 90ms/step - loss: 0.2824 - accuracy: 0.8534 - val_loss: 2.0838 - val_accuracy: 0.7143
# Epoch 299/2000
# 9/9 [==============================] - 1s 90ms/step - loss: 0.3225 - accuracy: 0.8195 - val_loss: 0.6761 - val_accuracy: 0.7857
# Epoch 300/2000
# 9/9 [==============================] - 1s 88ms/step - loss: 0.2821 - accuracy: 0.8421 - val_loss: 1.6770 - val_accuracy: 0.7857
# Epoch 301/2000
# 9/9 [==============================] - 1s 89ms/step - loss: 0.2874 - accuracy: 0.8271 - val_loss: 2.5360 - val_accuracy: 0.7857
# Epoch 302/2000
# 9/9 [==============================] - 1s 91ms/step - loss: 0.2823 - accuracy: 0.8045 - val_loss: 8.7492 - val_accuracy: 0.3571
# Epoch 303/2000
# 9/9 [==============================] - 1s 87ms/step - loss: 0.3667 - accuracy: 0.8308 - val_loss: 10.4952 - val_accuracy: 0.2143
# Epoch 304/2000
# 9/9 [==============================] - 1s 90ms/step - loss: 0.2838 - accuracy: 0.8083 - val_loss: 10.4281 - val_accuracy: 0.2143
# Epoch 305/2000
# 9/9 [==============================] - 1s 93ms/step - loss: 0.3701 - accuracy: 0.8308 - val_loss: 10.1909 - val_accuracy: 0.2143
# Epoch 306/2000
# 9/9 [==============================] - 1s 84ms/step - loss: 0.2486 - accuracy: 0.8271 - val_loss: 7.4139 - val_accuracy: 0.3571
# Epoch 307/2000
# 9/9 [==============================] - 1s 87ms/step - loss: 0.2636 - accuracy: 0.8459 - val_loss: 3.5718 - val_accuracy: 0.7143
# Epoch 308/2000
# 9/9 [==============================] - 1s 84ms/step - loss: 0.2653 - accuracy: 0.8684 - val_loss: 0.2846 - val_accuracy: 0.8571
# Epoch 309/2000
# 9/9 [==============================] - 1s 85ms/step - loss: 0.2482 - accuracy: 0.8496 - val_loss: 0.0514 - val_accuracy: 0.9286
# Epoch 310/2000
# 9/9 [==============================] - 1s 83ms/step - loss: 0.2544 - accuracy: 0.8835 - val_loss: 0.0505 - val_accuracy: 0.9286
# Epoch 311/2000
# 9/9 [==============================] - 1s 87ms/step - loss: 0.3199 - accuracy: 0.8647 - val_loss: 0.0520 - val_accuracy: 0.9286
# Epoch 312/2000
# 9/9 [==============================] - 1s 85ms/step - loss: 0.3075 - accuracy: 0.8496 - val_loss: 0.0539 - val_accuracy: 0.9286
# Epoch 313/2000
# 9/9 [==============================] - 1s 83ms/step - loss: 0.2270 - accuracy: 0.8534 - val_loss: 2.5645 - val_accuracy: 0.5714
# Epoch 314/2000
# 9/9 [==============================] - 1s 85ms/step - loss: 0.2982 - accuracy: 0.8195 - val_loss: 3.4953 - val_accuracy: 0.3571
# Epoch 315/2000
# 9/9 [==============================] - 1s 77ms/step - loss: 0.2576 - accuracy: 0.8383 - val_loss: 3.1797 - val_accuracy: 0.4286
# Epoch 316/2000
# 9/9 [==============================] - 1s 83ms/step - loss: 0.2704 - accuracy: 0.8346 - val_loss: 3.2244 - val_accuracy: 0.4286
# Epoch 317/2000
# 9/9 [==============================] - 1s 84ms/step - loss: 0.4058 - accuracy: 0.8647 - val_loss: 6.5654 - val_accuracy: 0.3571
# Epoch 318/2000
# 9/9 [==============================] - 1s 81ms/step - loss: 0.7078 - accuracy: 0.7820 - val_loss: 4.2599 - val_accuracy: 0.5000
# Epoch 319/2000
# 9/9 [==============================] - 1s 80ms/step - loss: 0.4620 - accuracy: 0.8158 - val_loss: 7.9176 - val_accuracy: 0.2857
# Epoch 320/2000
# 9/9 [==============================] - 1s 83ms/step - loss: 0.4858 - accuracy: 0.8045 - val_loss: 8.5878 - val_accuracy: 0.2857
# Epoch 321/2000
# 9/9 [==============================] - 1s 81ms/step - loss: 0.3854 - accuracy: 0.8346 - val_loss: 8.4275 - val_accuracy: 0.2857
# Epoch 322/2000
# 9/9 [==============================] - 1s 85ms/step - loss: 0.4139 - accuracy: 0.8008 - val_loss: 4.4161 - val_accuracy: 0.2857
# Epoch 323/2000
# 9/9 [==============================] - 1s 90ms/step - loss: 0.3746 - accuracy: 0.8308 - val_loss: 1.1138 - val_accuracy: 0.7857
# Epoch 324/2000
# 9/9 [==============================] - 1s 83ms/step - loss: 0.4041 - accuracy: 0.8308 - val_loss: 0.4534 - val_accuracy: 0.7857
# Epoch 325/2000
# 9/9 [==============================] - 1s 89ms/step - loss: 0.3011 - accuracy: 0.8233 - val_loss: 2.1670 - val_accuracy: 0.5714
# Epoch 326/2000
# 9/9 [==============================] - 1s 87ms/step - loss: 0.3353 - accuracy: 0.8383 - val_loss: 3.1928 - val_accuracy: 0.5714
# Epoch 327/2000
# 9/9 [==============================] - 1s 88ms/step - loss: 0.2838 - accuracy: 0.8571 - val_loss: 0.2089 - val_accuracy: 0.9286
# Epoch 328/2000
# 9/9 [==============================] - 1s 90ms/step - loss: 0.3247 - accuracy: 0.8383 - val_loss: 0.0487 - val_accuracy: 1.0000
# Epoch 329/2000
# 9/9 [==============================] - 1s 83ms/step - loss: 0.2600 - accuracy: 0.8271 - val_loss: 1.5965 - val_accuracy: 0.7857
# Epoch 330/2000
# 9/9 [==============================] - 1s 83ms/step - loss: 0.3206 - accuracy: 0.8195 - val_loss: 0.0493 - val_accuracy: 1.0000
# Epoch 331/2000
# 9/9 [==============================] - 1s 82ms/step - loss: 1.1492 - accuracy: 0.7068 - val_loss: 3.4326 - val_accuracy: 0.2143
# Epoch 332/2000
# 9/9 [==============================] - 1s 86ms/step - loss: 0.5004 - accuracy: 0.7895 - val_loss: 2.9265 - val_accuracy: 0.5000
# Epoch 333/2000
# 9/9 [==============================] - 1s 82ms/step - loss: 0.3738 - accuracy: 0.8045 - val_loss: 1.6414 - val_accuracy: 0.6429
# Epoch 334/2000
# 9/9 [==============================] - 1s 79ms/step - loss: 0.3319 - accuracy: 0.8571 - val_loss: 1.0728 - val_accuracy: 0.6429
# Epoch 335/2000
# ...
# Epoch 899/2000
# 9/9 [==============================] - 1s 128ms/step - loss: 0.2524 - accuracy: 0.9549 - val_loss: 5.3663 - val_accuracy: 0.5714
# Epoch 900/2000
# 9/9 [==============================] - 1s 128ms/step - loss: 0.1993 - accuracy: 0.9361 - val_loss: 5.2425 - val_accuracy: 0.3571
# Epoch 901/2000
# 9/9 [==============================] - 1s 126ms/step - loss: 0.1878 - accuracy: 0.9398 - val_loss: 10.8735 - val_accuracy: 0.3571
# Epoch 902/2000
# 9/9 [==============================] - 1s 137ms/step - loss: 0.2116 - accuracy: 0.9398 - val_loss: 3.3517 - val_accuracy: 0.6429
# Epoch 903/2000
# 9/9 [==============================] - 1s 128ms/step - loss: 0.1895 - accuracy: 0.9211 - val_loss: 2.4372 - val_accuracy: 0.7143
# Epoch 904/2000
# 9/9 [==============================] - 1s 137ms/step - loss: 0.1511 - accuracy: 0.9474 - val_loss: 2.9432 - val_accuracy: 0.7857
# Epoch 905/2000
# 9/9 [==============================] - 1s 133ms/step - loss: 0.1425 - accuracy: 0.9624 - val_loss: 3.1701 - val_accuracy: 0.7857
# Epoch 906/2000
# 9/9 [==============================] - 1s 142ms/step - loss: 0.1492 - accuracy: 0.9398 - val_loss: 2.5254 - val_accuracy: 0.8571
# Epoch 907/2000
# 9/9 [==============================] - 1s 116ms/step - loss: 0.1859 - accuracy: 0.9474 - val_loss: 1.7565 - val_accuracy: 0.8571
# Epoch 908/2000
# 9/9 [==============================] - 1s 90ms/step - loss: 0.1535 - accuracy: 0.9361 - val_loss: 0.0107 - val_accuracy: 1.0000
# Epoch 909/2000
# 9/9 [==============================] - 1s 93ms/step - loss: 0.1622 - accuracy: 0.9511 - val_loss: 12.1818 - val_accuracy: 0.2857
# Epoch 910/2000
# 9/9 [==============================] - 1s 92ms/step - loss: 0.1542 - accuracy: 0.9398 - val_loss: 7.3572 - val_accuracy: 0.3571
# Epoch 911/2000
# 9/9 [==============================] - 1s 84ms/step - loss: 0.1443 - accuracy: 0.9586 - val_loss: 7.2884 - val_accuracy: 0.4286
# Epoch 912/2000
# 9/9 [==============================] - 1s 81ms/step - loss: 0.1854 - accuracy: 0.9436 - val_loss: 8.2431 - val_accuracy: 0.4286
# Epoch 913/2000
# 9/9 [==============================] - 1s 82ms/step - loss: 0.1347 - accuracy: 0.9474 - val_loss: 7.7116 - val_accuracy: 0.3571
# Epoch 914/2000
# 9/9 [==============================] - 1s 89ms/step - loss: 0.1918 - accuracy: 0.9361 - val_loss: 3.3040 - val_accuracy: 0.5714
# Epoch 915/2000
# 9/9 [==============================] - 1s 84ms/step - loss: 0.1701 - accuracy: 0.9474 - val_loss: 1.5583 - val_accuracy: 0.9286
# Epoch 916/2000
# 9/9 [==============================] - 1s 86ms/step - loss: 0.1892 - accuracy: 0.9436 - val_loss: 1.2173 - val_accuracy: 0.9286
# Epoch 917/2000
# 9/9 [==============================] - 1s 88ms/step - loss: 0.1440 - accuracy: 0.9699 - val_loss: 4.0034 - val_accuracy: 0.6429
# Epoch 918/2000
# 9/9 [==============================] - 1s 83ms/step - loss: 0.1653 - accuracy: 0.9474 - val_loss: 10.3578 - val_accuracy: 0.3571
# Epoch 919/2000
# 9/9 [==============================] - 1s 86ms/step - loss: 0.1391 - accuracy: 0.9436 - val_loss: 6.7171 - val_accuracy: 0.3571
# Epoch 920/2000
# 9/9 [==============================] - 1s 86ms/step - loss: 0.2894 - accuracy: 0.8947 - val_loss: 7.9883 - val_accuracy: 0.3571
# Epoch 921/2000
# 9/9 [==============================] - 1s 83ms/step - loss: 0.3767 - accuracy: 0.9135 - val_loss: 11.6638 - val_accuracy: 0.2143
# Epoch 922/2000
# 9/9 [==============================] - 1s 81ms/step - loss: 0.4190 - accuracy: 0.8797 - val_loss: 1.1683 - val_accuracy: 0.8571
# Epoch 923/2000
# 9/9 [==============================] - 1s 81ms/step - loss: 0.1665 - accuracy: 0.9398 - val_loss: 2.4606 - val_accuracy: 0.6429
# Epoch 924/2000
# 9/9 [==============================] - 1s 86ms/step - loss: 0.3293 - accuracy: 0.9248 - val_loss: 5.4039 - val_accuracy: 0.4286
# Epoch 925/2000
# 9/9 [==============================] - 1s 84ms/step - loss: 0.2540 - accuracy: 0.8872 - val_loss: 3.8753 - val_accuracy: 0.6429
# Epoch 926/2000
# 9/9 [==============================] - 1s 82ms/step - loss: 0.2899 - accuracy: 0.8872 - val_loss: 1.1771 - val_accuracy: 0.8571
# Epoch 927/2000
# 9/9 [==============================] - 1s 86ms/step - loss: 0.2292 - accuracy: 0.9361 - val_loss: 1.7807 - val_accuracy: 0.7143
# Epoch 928/2000
# 9/9 [==============================] - 1s 84ms/step - loss: 0.1434 - accuracy: 0.9474 - val_loss: 0.6538 - val_accuracy: 0.9286
# Epoch 929/2000
# 9/9 [==============================] - 1s 85ms/step - loss: 0.1060 - accuracy: 0.9774 - val_loss: 1.3562 - val_accuracy: 0.9286
# Epoch 930/2000
# 9/9 [==============================] - 1s 86ms/step - loss: 0.1813 - accuracy: 0.9436 - val_loss: 1.4097 - val_accuracy: 0.7857
# Epoch 931/2000
# 9/9 [==============================] - 1s 83ms/step - loss: 0.1230 - accuracy: 0.9662 - val_loss: 2.6293 - val_accuracy: 0.7143
# Epoch 932/2000
# 9/9 [==============================] - 1s 85ms/step - loss: 0.1702 - accuracy: 0.9398 - val_loss: 0.2324 - val_accuracy: 0.8571
# Epoch 933/2000
# 9/9 [==============================] - 1s 84ms/step - loss: 0.1776 - accuracy: 0.9436 - val_loss: 0.6079 - val_accuracy: 0.9286
# Epoch 934/2000
# 9/9 [==============================] - 1s 85ms/step - loss: 0.1573 - accuracy: 0.9474 - val_loss: 0.1048 - val_accuracy: 0.9286
# Epoch 935/2000
# 9/9 [==============================] - 1s 85ms/step - loss: 0.1652 - accuracy: 0.9398 - val_loss: 0.0131 - val_accuracy: 1.0000
# Epoch 936/2000
# 9/9 [==============================] - 1s 83ms/step - loss: 0.2118 - accuracy: 0.9474 - val_loss: 2.6443 - val_accuracy: 0.7143
# Epoch 937/2000
# 9/9 [==============================] - 1s 83ms/step - loss: 0.1517 - accuracy: 0.9662 - val_loss: 5.9446 - val_accuracy: 0.5714
# Epoch 938/2000
# 9/9 [==============================] - 1s 84ms/step - loss: 0.3089 - accuracy: 0.9286 - val_loss: 4.2852 - val_accuracy: 0.6429
# Epoch 939/2000
# 9/9 [==============================] - 1s 92ms/step - loss: 0.1598 - accuracy: 0.9436 - val_loss: 8.0623 - val_accuracy: 0.1429
# Epoch 940/2000
# 9/9 [==============================] - 1s 87ms/step - loss: 0.4482 - accuracy: 0.8797 - val_loss: 8.0927 - val_accuracy: 0.1429
# Epoch 941/2000
# 9/9 [==============================] - 1s 94ms/step - loss: 0.2107 - accuracy: 0.9436 - val_loss: 3.2816 - val_accuracy: 0.7143
# Epoch 942/2000
# 9/9 [==============================] - 1s 88ms/step - loss: 0.1585 - accuracy: 0.9586 - val_loss: 1.8236 - val_accuracy: 0.7857
# Epoch 943/2000
# 9/9 [==============================] - 1s 91ms/step - loss: 0.2993 - accuracy: 0.9023 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 944/2000
# 9/9 [==============================] - 1s 92ms/step - loss: 0.4460 - accuracy: 0.8985 - val_loss: 1.6516 - val_accuracy: 0.8571
# Epoch 945/2000
# 9/9 [==============================] - 1s 93ms/step - loss: 0.1861 - accuracy: 0.9323 - val_loss: 3.7676 - val_accuracy: 0.5714
# Epoch 946/2000
# 9/9 [==============================] - 1s 90ms/step - loss: 0.1323 - accuracy: 0.9549 - val_loss: 1.6523 - val_accuracy: 0.7143
# Epoch 947/2000
# 9/9 [==============================] - 1s 85ms/step - loss: 0.1939 - accuracy: 0.9286 - val_loss: 1.0360 - val_accuracy: 0.8571
# Epoch 948/2000
# 9/9 [==============================] - 1s 87ms/step - loss: 0.2244 - accuracy: 0.9211 - val_loss: 9.7747 - val_accuracy: 0.2143
# Epoch 949/2000
# 9/9 [==============================] - 1s 84ms/step - loss: 0.2901 - accuracy: 0.9398 - val_loss: 2.6037 - val_accuracy: 0.7143
# Epoch 950/2000
# 9/9 [==============================] - 1s 85ms/step - loss: 0.4604 - accuracy: 0.9023 - val_loss: 6.3152e-04 - val_accuracy: 1.0000
# Epoch 951/2000
# 9/9 [==============================] - 1s 86ms/step - loss: 0.1792 - accuracy: 0.9474 - val_loss: 2.2893 - val_accuracy: 0.7143
# Epoch 952/2000
# 9/9 [==============================] - 1s 84ms/step - loss: 0.1484 - accuracy: 0.9511 - val_loss: 5.4984 - val_accuracy: 0.5000
# Epoch 953/2000
# 9/9 [==============================] - 1s 86ms/step - loss: 0.1090 - accuracy: 0.9662 - val_loss: 1.8331 - val_accuracy: 0.7143
# Epoch 954/2000
# 9/9 [==============================] - 1s 84ms/step - loss: 0.1251 - accuracy: 0.9662 - val_loss: 1.2022 - val_accuracy: 0.8571
# Epoch 955/2000
# 9/9 [==============================] - 1s 81ms/step - loss: 0.1254 - accuracy: 0.9586 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 956/2000
# 9/9 [==============================] - ETA: 0s - loss: 0.1099 - accuracy: 0.9699
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3860\2168670196.py in ?()
#       1 # Fit the model with both TensorBoard and EarlyStopping callbacks
# ----> 2 history = model.fit(
#       3     X_train, y_train,
#       4     epochs=2000,
#       5     validation_data=(X_test, y_test),
#
# c:\Users\StrawHat\anaconda3\envs\samvaad\lib\site-packages\keras\utils\traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# c:\Users\StrawHat\anaconda3\envs\samvaad\lib\site-packages\keras\engine\training.py in ?(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1620                         "val_" + name: val for name, val in val_logs.items()
#    1621                     }
#    1622                     epoch_logs.update(val_logs)
#    1623
# -> 1624                 callbacks.on_epoch_end(epoch, epoch_logs)
#    1625                 training_logs = epoch_logs
#    1626                 if self.stop_training:
#    1627                     break
#
# c:\Users\StrawHat\anaconda3\envs\samvaad\lib\site-packages\keras\callbacks.py in ?(self, epoch, logs)
#     444               keys are prefixed with `val_`.
#     445         """
#     446         logs = self._process_logs(logs)
#     447         for callback in self.callbacks:
# --> 448             callback.on_epoch_end(epoch, logs)
#
# c:\Users\StrawHat\anaconda3\envs\samvaad\lib\site-packages\keras\callbacks.py in ?(self, epoch, logs)
#    2734         """Runs metrics and histogram summaries at epoch end."""
#    2735         self._log_epoch_metrics(epoch, logs)
#    2736
#    2737         if self.histogram_freq and epoch % self.histogram_freq == 0:
# -> 2738             self._log_weights(epoch)
#    2739
#    2740         if self.embeddings_freq and epoch % self.embeddings_freq == 0:
#    2741             self._log_embeddings(epoch)
#
# c:\Users\StrawHat\anaconda3\envs\samvaad\lib\site-packages\keras\callbacks.py in ?(self, epoch)
#    2805                     for weight in layer.weights:
#    2806                         weight_name = weight.name.replace(":", "_")
#    2807                         # Add a suffix to prevent summary tag name collision.
#    2808                         histogram_weight_name = weight_name + "/histogram"
# -> 2809                         tf.summary.histogram(
#    2810                             histogram_weight_name, weight, step=epoch
#    2811                         )
#    2812                         if self.write_images:
#
# c:\Users\StrawHat\anaconda3\envs\samvaad\lib\site-packages\tensorboard\plugins\histogram\summary_v2.py in ?(name, data, step, buckets, description)
#     192         @lazy_tensor_creator.LazyTensorCreator
#     193         def lazy_tensor():
#     194             return _buckets(data, buckets)
#     195
# --> 196         return tf.summary.write(
#     197             tag=tag,
#     198             tensor=lazy_tensor,
#     199             step=step,
#
# c:\Users\StrawHat\anaconda3\envs\samvaad\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py in ?(tag, tensor, step, metadata, name)
#     765             name=scope)
#     766         with ops.control_dependencies([write_summary_op]):
#     767           return constant_op.constant(True)
#     768
# --> 769     op = smart_cond.smart_cond(
#     770         should_record_summaries(), record, _nothing, name="summary_cond")
#     771     if not context.executing_eagerly():
#     772       ops.add_to_collection(ops.GraphKeys._SUMMARY_COLLECTION, op)  # pylint: disable=protected-access
#
# c:\Users\StrawHat\anaconda3\envs\samvaad\lib\site-packages\tensorflow\python\framework\smart_cond.py in ?(pred, true_fn, false_fn, name)
#      48
#      49   pred_value = smart_constant_value(pred)
#      50   if pred_value is not None:
#      51     if pred_value:
# ---> 52       return true_fn()
#      53     else:
#      54       return false_fn()
#      55   else:
#
# c:\Users\StrawHat\anaconda3\envs\samvaad\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py in ?()
#     753                          "tf.summary.experimental.set_step()")
#     754
#     755       # Note the identity to move the tensor to the CPU.
#     756       with ops.device("cpu:0"):
# --> 757         summary_tensor = tensor() if callable(tensor) else array_ops.identity(
#     758             tensor)
#     759         write_summary_op = gen_summary_ops.write_summary(
#     760             _summary_state.writer._resource,  # pylint: disable=protected-access
#
# c:\Users\StrawHat\anaconda3\envs\samvaad\lib\site-packages\tensorboard\util\lazy_tensor_creator.py in ?(self)
#      62                         "Cannot use LazyTensorCreator with reentrant callable"
#      63                     )
#      64                 elif self._tensor is None:
#      65                     self._tensor = _CALL_IN_PROGRESS_SENTINEL
# ---> 66                     self._tensor = self._tensor_callable()
#      67         return self._tensor
#
# c:\Users\StrawHat\anaconda3\envs\samvaad\lib\site-packages\tensorboard\plugins\histogram\summary_v2.py in ?()
#     192         @lazy_tensor_creator.LazyTensorCreator
#     193         def lazy_tensor():
# --> 194             return _buckets(data, buckets)
#
# c:\Users\StrawHat\anaconda3\envs\samvaad\lib\site-packages\tensorboard\plugins\histogram\summary_v2.py in ?(data, bucket_count)
#     224         data = tf.reshape(data, shape=[-1])  # flatten
#     225         data = tf.cast(data, tf.float64)
#     226         data_size = tf.size(input=data)
#     227         is_empty = tf.logical_or(
# --> 228             tf.equal(data_size, 0), tf.less_equal(bucket_count, 0)
#     229         )
#     230
#     231         def when_empty():
#
# c:\Users\StrawHat\anaconda3\envs\samvaad\lib\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# c:\Users\StrawHat\anaconda3\envs\samvaad\lib\site-packages\tensorflow\python\util\dispatch.py in ?(*args, **kwargs)
#    1173
#    1174       # Fallback dispatch system (dispatch v1):
#    1175       try:
#    1176         return dispatch_target(*args, **kwargs)
# -> 1177       except (TypeError, ValueError):
#    1178         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179         # TypeError, when given unexpected types.  So we need to catch both.
#    1180         result = dispatch(op_dispatch_handler, args, kwargs)
#
# c:\Users\StrawHat\anaconda3\envs\samvaad\lib\site-packages\tensorflow\python\ops\math_ops.py in ?(x, y, name)
#    1919
#    1920   Raises:
#    1921     `tf.errors.InvalidArgumentError`: If shapes of arguments are incompatible
#    1922   """
# -> 1923   return gen_math_ops.equal(x, y, name=name)
#
# c:\Users\StrawHat\anaconda3\envs\samvaad\lib\site-packages\tensorflow\python\ops\gen_math_ops.py in ?(x, y, incompatible_shape_error, name)
#    3302         incompatible_shape_error)
#    3303       return _result
#    3304     except _core._NotOkStatusException as e:
#    3305       _ops.raise_from_not_ok_status(e, name)
# -> 3306     except _core._FallbackException:
#    3307       pass
#    3308     try:
#    3309       return equal_eager_fallback(
#
# KeyboardInterrupt:

# %% [markdown]
# Mdoel Save and Reload

# %%
model.save('actionlstm7.h5')

# %%
model.load_weights('actionlstm7.h5')

# %% [markdown]
# Evaluation

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_test)
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# 1/1 [==============================] - 2s 2s/step
# array([[[13,  0],
#         [ 0,  1]],
#
#        [[ 9,  0],
#         [ 0,  5]],
#
#        [[12,  0],
#         [ 0,  2]],
#
#        [[11,  0],
#         [ 0,  3]],
#
#        [[13,  0],
#         [ 0,  1]],
#
#        [[12,  0],
#         [ 0,  2]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 1.0

# %%
from scipy import stats

# %%
colors = [(245,117,16), (117,245,16), (16,117,245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        if num < len(colors):  # Check if index is within bounds
            cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
            cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
plt.figure(figsize=(18,18))
plt.imshow(prob_viz(res, actions, image, colors))

# %% [markdown]
# Live Testing

# %%
# 1. New detection variables
sequence = []
sentence = []
predictions = []
threshold = 0.7

cap = cv2.VideoCapture(1)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
            
            
        #3. Viz logic
            if np.unique(predictions[-10:])[0]==np.argmax(res): 
                if res[np.argmax(res)] > threshold: 
                    
                    if len(sentence) > 0: 
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# A

# %%
sequence = []
sentence = []

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            predicted_action = actions[np.argmax(res)]
            print(predicted_action)
            
            # Update sentence
            if len(sentence) > 0: 
                if predicted_action != sentence[-1]:
                    sentence.append(predicted_action)
            else:
                sentence.append(predicted_action)

            # Keep only the last 5 actions in the sentence
            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Display predicted action on the top
            cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
            cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# F
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# G
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# G
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# G
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# G
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# G
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# G
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# G
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# G
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# G
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# G
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# G
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# G
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# G
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# G
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# G
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# G
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# G
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# G
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# G
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# G
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# G
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# G
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# G
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# G
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# G
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# E
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# B
